# %% [markdown]
# <a href="https://colab.research.google.com/github/Obiascpe/OBIAS_CPE-009A-CPE12S2-OOP/blob/main/OBIAS_Control_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Name:** Obias, Jave Joaquin C.
#
# **Section:** CPE12S2
#
# **Date:** January 15, 2026

# %% [markdown]
# ### **If Statement**

# %%
a, b = 12, 100
if b > a:
  print("b is greater than a")
# Out:
# b is greater than a

# %% [markdown]
# ### **Elif Statement**

# %%
a, b = 12, 12
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a and b are equal

# %% [markdown]
# ### **Else Statement**

# %%
a, b = 200, 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# ### **Short Hand If Statement**

# %%
a, b = 12, 100
if b > a: print("b is greater than a")
# Out:
# b is greater than a

# %% [markdown]
# ### **Short Hand If... Else Statement**

# %%
a, b = 2, 330
print("A") if a > b else print("B")
# Out:
# B

# %% [markdown]
# ### **And-Both Conditions are True**

# %%
a, b, c = 200, 33, 500
if a > b and c > a:
  print("Both conditions are True")
# Out:
# Both conditions are True

# %% [markdown]
# ### **Or-Atleast One of the Condition is True**

# %%
if a > b or a > c:
  print("Atleast one of the conditions is True")
# Out:
# Atleast one of the conditions is True

# %% [markdown]
# ### **Nested If**

# %%
x = 41

if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20!")
    if x > 30:
      print("and also above 30!")
    else:
      print("below 30")
  else:
    print("but not above 20.")
else:
  print("below 10")
# Out:
# Above ten,
# and also above 20!
# and also above 30!

# %% [markdown]
# ### **Supplementary Activity**

# %%
print("Enter your age:")
age = int(input())
if age >= 18:
  print("You are qualified to vote")
else:
  print("You are not qualified to vote")

#Plus 2
# Out:
# Enter your age:
# 18
# You are qualified to vote
